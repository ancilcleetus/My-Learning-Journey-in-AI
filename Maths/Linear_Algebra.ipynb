# %% [markdown]
# # **Math - Linear Algebra**

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 📖 TABLE OF CONTENTS
#
# - [Intro to Linear Algebra](#Intro-to-Linear-Algebra)
# - [Vectors](#Vectors)
#   - [Definition](#Definition)
#   - [Purpose](#Purpose)
#   - [Vectors in Python](#Vectors-in-Python)
#   - [Plotting vectors](#Plotting-vectors)
#     - [2D vectors](#2D-vectors)
#     - [3D vectors](#3D-vectors)
#   - [Norm](#Norm)
#   - [Addition](#Addition)
#   - [Geometric Translation](#Geometric-Translation)
#   - [Subtraction](#Subtraction)
#   - [Multiplication by a scalar](#Multiplication-by-a-scalar)
#   - [Division by a scalar](#Division-by-a-scalar)
#   - [Zero, unit and normalized vectors](#Zero,-unit-and-normalized-vectors)
#   - [Dot product](#Dot-product)
#     - [Main properties](#Main-properties)
#     - [Calculating the angle between vectors](#Calculating-the-angle-between-vectors)
#     - [Projecting a point onto an axis](#Projecting-a-point-onto-an-axis)
# - [References](#References)

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Intro to Linear Algebra

# %% [markdown]
# *Linear Algebra is the branch of mathematics that studies [vector spaces](https://en.wikipedia.org/wiki/Vector_space) and linear transformations between vector spaces, such as rotating a shape, scaling it up or down, translating it (i.e. moving it), etc.*
#
# *Machine Learning relies heavily on Linear Algebra, so it is essential to understand what vectors and matrices are, what operations you can perform with them, and how they can be useful.*

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Vectors

# %% [markdown]
# ## Definition

# %% [markdown]
# A vector is a quantity defined by a magnitude and a direction. For example, a rocket's velocity is a 3-dimensional vector: its magnitude is the speed of the rocket, and its direction is (hopefully) up. A vector can be represented by an array of numbers called *scalars*. Each scalar corresponds to the magnitude of the vector with regards to each dimension.
#
# For example, say the rocket is going up at a slight angle: it has a vertical speed of 5,000 m/s, and also a slight speed towards the East at 10 m/s, and a slight speed towards the North at 50 m/s. The rocket's velocity may be represented by the following vector:
#
# **velocity** $= \begin{pmatrix}
# 10 \\
# 50 \\
# 5000 \\
# \end{pmatrix}$
#
# Note: by convention vectors are generally presented in the form of columns. Also, vector names are usually lowercase to distinguish them from matrices (which we will discuss below) and in bold (when possible) to distinguish them from simple scalar values such as ${meters\_per\_second} = 5026$.
#
# A list of N numbers may also represent the coordinates of a point in an N-dimensional space, so it is quite frequent to represent vectors as simple points instead of arrows. A vector with 1 element may be represented as an arrow or a point on an axis, a vector with 2 elements is an arrow or a point on a plane, a vector with 3 elements is an arrow or a point in space, and a vector with N elements is an arrow or a point in an N-dimensional space… which most people find hard to imagine.

# %% [markdown]
# ## Purpose

# %% [markdown]
# Vectors have many purposes in Machine Learning, most notably to represent observations and predictions. For example, say we built a Machine Learning system to classify videos into 3 categories (good, spam, clickbait) based on what we know about them. For each video, we would have a vector representing what we know about it, such as:
#
# **video** $= \begin{pmatrix}
# 10.5 \\
# 5.2 \\
# 3.25 \\
# 7.0
# \end{pmatrix}$
#
# This vector could represent a video that lasts 10.5 minutes, but only 5.2% viewers watch for more than a minute, it gets 3.25 views per day on average, and it was flagged 7 times as spam. As you can see, each axis may have a different meaning.
#
# Based on this vector our Machine Learning system may predict that there is an 80% probability that it is a spam video, 18% that it is clickbait, and 2% that it is a good video. This could be represented as the following vector:
#
# **class_probabilities** $= \begin{pmatrix}
# 0.80 \\
# 0.18 \\
# 0.02
# \end{pmatrix}$

# %% [markdown]
# ## Vectors in Python

# %% [markdown]
# In python, a vector can be represented in many ways, the simplest being a regular python list of numbers:

# %%
[10.5, 5.2, 3.25, 7.0]
# Out:
# [10.5, 5.2, 3.25, 7.0]

# %% [markdown]
# Since we plan to do quite a lot of scientific calculations, it is much better to use NumPy's `ndarray`, which provides a lot of convenient and optimized implementations of essential mathematical operations on vectors (for more details about NumPy, check out the [NumPy tutorial](https://nbviewer.org/github/ancilcleetus/My-Learning-Journey-in-AI/blob/main/Tools/NumPy.ipynb)). For example:

# %%
import numpy as np

video = np.array([10.5, 5.2, 3.25, 7.0])
video
# Out:
# array([10.5 ,  5.2 ,  3.25,  7.  ])

# %% [markdown]
# The size of a vector can be obtained using the `size` attribute:

# %%
video.size
# Out:
# 4

# %% [markdown]
# The $i^{th}$ element (also called *entry* or *item*) of a vector $\textbf{v}$ is noted $\textbf{v}_i$.
#
# Note that indices in mathematics generally start at 1, but in programming they usually start at 0. So to access $\textbf{video}_3$ programmatically, we would write:

# %%
video[2]  # 3rd element
# Out:
# np.float64(3.25)

# %% [markdown]
# ## Plotting vectors

# %% [markdown]
# To plot vectors we will use Matplotlib, so let's start by importing it (for details about Matplotlib, check the [Matplotlib tutorial](https://nbviewer.org/github/ancilcleetus/My-Learning-Journey-in-AI/blob/main/Tools/Matplotlib.ipynb)):

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2D vectors

# %% [markdown]
# Let's create a couple of very simple 2D vectors to plot:

# %%
u = np.array([2, 5])
v = np.array([3, 1])

# %% [markdown]
# These vectors each have 2 elements, so they can easily be represented graphically on a 2D graph, for example as points:

# %%
print(f"u = {u}")
print(f"v = {v}")
x_coords, y_coords = zip(u, v)
plt.scatter(x_coords, y_coords, color=["r", "b"])
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()
# Out:
# u = [2 5]
# v = [3 1]

# %% [markdown]
# Vectors can also be represented as arrows. Let's create a small convenience function to draw nice arrows:

# %%
def plot_vector2d(vector2d, origin=[0, 0], **options):
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],
              head_width=0.2, head_length=0.3, length_includes_head=True,
              **options)

# %% [markdown]
# Now let's draw the vectors **u** and **v** as arrows:

# %%
print(f"u = {u}")
print(f"v = {v}")
plot_vector2d(u, color="r")
plot_vector2d(v, color="b")
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()
# Out:
# u = [2 5]
# v = [3 1]

# %% [markdown]
# ### 3D vectors

# %% [markdown]
# Plotting 3D vectors is also relatively straightforward. First, let's create two 3D vectors:

# %%
a = np.array([1, 2, 8])
b = np.array([5, 6, 3])

# %% [markdown]
# Now let's plot them using matplotlib's `Axes3D`:

# %%
print(f"a = {a}")
print(f"b = {b}")
subplot3d = plt.subplot(111, projection='3d')
x_coords, y_coords, z_coords = zip(a,b)
subplot3d.scatter(x_coords, y_coords, z_coords)
subplot3d.set_zlim3d([0, 9])
plt.show()
# Out:
# a = [1 2 8]
# b = [5 6 3]

# %% [markdown]
# It is a bit hard to visualize exactly where in space these two points are, so let's add vertical lines. We'll create a small convenience function to plot a list of 3d vectors with vertical lines attached:

# %%
def plot_vectors3d(ax, vectors3d, z0, **options):
    for v in vectors3d:
        x, y, z = v
        ax.plot([x,x], [y,y], [z0, z], color="gray", linestyle='dotted', marker=".")
    x_coords, y_coords, z_coords = zip(*vectors3d)
    ax.scatter(x_coords, y_coords, z_coords, **options)

print(f"a = {a}")
print(f"b = {b}")
subplot3d = plt.subplot(111, projection='3d')
subplot3d.set_zlim([0, 9])
plot_vectors3d(subplot3d, [a,b], 0, color=("r","b"))
plt.show()
# Out:
# a = [1 2 8]
# b = [5 6 3]

# %% [markdown]
# ## Norm

# %% [markdown]
# The norm of a vector $\textbf{u}$, noted $\left \Vert \textbf{u} \right \|$, is a measure of the length (a.k.a. the magnitude) of $\textbf{u}$. There are multiple possible norms, but the most common one (and the only one we will discuss here) is the Euclidian norm, which is defined as:
#
# $\left \Vert \textbf{u} \right \| = \sqrt{\sum_{i}{\textbf{u}_i}^2}$
#
# That's the square root of the sum of all the squares of the components of $\textbf{u}$. We could implement this easily in pure python, recalling that $\sqrt x = x^{\frac{1}{2}}$

# %%
def vector_norm(vector):
    squares = [x**2 for x in vector]
    return (sum(squares))**0.5

print(f"u = {u}")
print(f"|u| = {vector_norm(u)}")
# Out:
# u = [2 5]
# |u| = 5.385164807134504

# %% [markdown]
# However, it is much more efficient to use NumPy's `norm` function, available in the `linalg` (**Lin**ear **Alg**ebra) module:

# %%
import numpy.linalg as la

print(f"u = {u}")
print(f"|u| = {la.norm(u)}")
# Out:
# u = [2 5]
# |u| = 5.385164807134504

# %% [markdown]
# Let's plot a little diagram to confirm that the length of vector $\textbf{u}$ is indeed $\approx5.4$:

# %%
radius = la.norm(u)
print(f"u = {u}")
print(f"radius = |u| = {radius}")
plt.gca().add_artist(plt.Circle((0, 0), radius, color="grey"))
plot_vector2d(u, color="red")

plt.axis([0, 9, 0, 6])
plt.gca().set_aspect("equal")
plt.grid()
plt.show()
# Out:
# u = [2 5]
# radius = |u| = 5.385164807134504

# %% [markdown]
# ## Addition
# Vectors of same size can be added together. Addition is performed *elementwise*:

# %%
print(f"  {u}")
print(f"  {v}")
print("-"*10)
print(f"= {u + v}")
# Out:
#   [2 5]
#   [3 1]
# ----------
# = [5 6]

# %% [markdown]
# Let's look at what vector addition looks like graphically:

# %%
print(f"u = {u}")
print(f"v = {v}")
print(f"u + v = {u + v}")

plot_vector2d(u, color="red")
plot_vector2d(v, color="blue")
plot_vector2d(v, origin=u, color="blue", linestyle="dotted")
plot_vector2d(u, origin=v, color="red", linestyle="dotted")
plot_vector2d(u + v, color="green")
plt.text(0.7, 3, "u", color="red", fontsize=18)
plt.text(1.8, 0.2, "v", color="blue", fontsize=18)
plt.text(4, 3, "u", color="red", fontsize=18)
plt.text(3.5, 5.6, "v", color="blue", fontsize=18)
plt.text(2.5, 2.5, "u+v", color="green", fontsize=18)

plt.axis([0, 9, 0, 7])
plt.gca().set_aspect("equal")
plt.grid()
plt.show()
# Out:
# u = [2 5]
# v = [3 1]
# u + v = [5 6]

# %% [markdown]
# Vector addition is **commutative**, meaning that $\textbf{u} + \textbf{v} = \textbf{v} + \textbf{u}$. You can see it on the previous image: following $\textbf{u}$ *then* $\textbf{v}$ leads to the same point as following $\textbf{v}$ *then* $\textbf{u}$.
#
# Vector addition is also **associative**, meaning that $\textbf{u} + (\textbf{v} + \textbf{w}) = (\textbf{u} + \textbf{v}) + \textbf{w}$.

# %% [markdown]
# ## Geometric Translation

# %% [markdown]
# If you have a shape defined by a number of points (vectors), and you add a vector $\textbf{v}$ to all of these points, then the whole shape gets shifted by $\textbf{v}$. This is called a [geometric translation](https://en.wikipedia.org/wiki/Translation_%28geometry%29):

# %%
t1 = np.array([2, 0.25])
t2 = np.array([2.5, 3.5])
t3 = np.array([1, 2])

print(f"t1 = {t1}")
print(f"t2 = {t2}")
print(f"t3 = {t3}")

x_coords, y_coords = zip(t1, t2, t3, t1)  # repeat first point to close the shape
plt.plot(x_coords, y_coords, linestyle="--", color="cyan", marker="o")

plot_vector2d(v, origin=t1, color="red", linestyle=":")
plot_vector2d(v, origin=t2, color="red", linestyle=":")
plot_vector2d(v, origin=t3, color="red", linestyle=":")

t1b = t1 + v
t2b = t2 + v
t3b = t3 + v

print(f"v = {v}")
print(f"t1 + v = {t1b}")
print(f"t2 + v = {t2b}")
print(f"t3 + v = {t3b}")

x_coords, y_coords = zip(t1b, t2b, t3b, t1b)  # repeat first point to close the shape
plt.plot(x_coords, y_coords, linestyle="-", color="blue", marker="o")

plt.text(4, 4.2, "v", color="red", fontsize=18)
plt.text(3, 2.3, "v", color="red", fontsize=18)
plt.text(3.5, 0.4, "v", color="red", fontsize=18)

plt.axis([0, 6, 0, 5])
plt.gca().set_aspect("equal")
plt.grid()
plt.show()
# Out:
# t1 = [2.   0.25]
# t2 = [2.5 3.5]
# t3 = [1 2]
# v = [3 1]
# t1 + v = [5.   1.25]
# t2 + v = [5.5 4.5]
# t3 + v = [4 3]

# %% [markdown]
# ## Subtraction
# Subtracting a vector is like adding the opposite vector.

# %% [markdown]
# ## Multiplication by a scalar
# Vectors can be multiplied by scalars. All elements in the vector are multiplied by that number, for example:

# %%
print("1.5 *", u, "=")

1.5 * u
# Out:
# 1.5 * [2 5] =
# array([3. , 7.5])

# %% [markdown]
# Graphically, scalar multiplication results in changing the scale of a figure, hence the name *scalar*. The distance from the origin (the point at coordinates equal to zero) is also multiplied by the scalar. For example, let's scale up by a factor of `k = 2.5`:

# %%
print(f"t1 = {t1}")
print(f"t2 = {t2}")
print(f"t3 = {t3}")

k = 2.5
t1c = k * t1
t2c = k * t2
t3c = k * t3

print(f"k = {k}")
print(f"k * t1 = {t1c}")
print(f"k * t2 = {t2c}")
print(f"k * t3 = {t3c}")

x_coords, y_coords = zip(t1, t2, t3, t1)  # repeat first point to close the shape
plt.plot(x_coords, y_coords, linestyle="--", color="red", marker="o")

plot_vector2d(t1, color="red")
plot_vector2d(t2, color="red")
plot_vector2d(t3, color="red")

x_coords, y_coords = zip(t1c, t2c, t3c, t1c)  # repeat first point to close the shape
plt.plot(x_coords, y_coords, linestyle="-", color="blue", marker="o")

plot_vector2d(t1c, color="blue", linestyle=":")
plot_vector2d(t2c, color="blue", linestyle=":")
plot_vector2d(t3c, color="blue", linestyle=":")

plt.axis([0, 9, 0, 9])
plt.gca().set_aspect("equal")
plt.grid()
plt.show()
# Out:
# t1 = [2.   0.25]
# t2 = [2.5 3.5]
# t3 = [1 2]
# k = 2.5
# k * t1 = [5.    0.625]
# k * t2 = [6.25 8.75]
# k * t3 = [2.5 5. ]

# %% [markdown]
# Scalar multiplication is **commutative**: $\lambda \times \textbf{u} = \textbf{u} \times \lambda$.
#
# It is also **associative**: $\lambda_1 \times (\lambda_2 \times \textbf{u}) = (\lambda_1 \times \lambda_2) \times \textbf{u}$.
#
# Finally, it is **distributive** over addition of vectors: $\lambda \times (\textbf{u} + \textbf{v}) = \lambda \times \textbf{u} + \lambda \times \textbf{v}$.

# %% [markdown]
# ## Division by a scalar
# As you might guess, dividing a vector by a scalar is equivalent to multiplying by its multiplicative inverse (reciprocal):
#
# $\dfrac{\textbf{u}}{\lambda} = \dfrac{1}{\lambda} \times \textbf{u}$

# %% [markdown]
# ## Zero, unit and normalized vectors
# * A **zero-vector** is a vector full of 0s.
# * A **unit vector** is a vector with a norm equal to 1.
# * The **normalized vector** of a non-null vector $\textbf{v}$, noted $\hat{\textbf{v}}$, is the unit vector that points in the same direction as $\textbf{v}$. It is equal to: $\hat{\textbf{v}} = \dfrac{\textbf{v}}{\left \Vert \textbf{v} \right \|}$

# %%
print(f"v = {v}")
print(f"|v| = {la.norm(v)}")
print(f"v_hat = {v/la.norm(v)}")

plt.gca().add_artist(plt.Circle((0, 0), 1, color="cyan"))
plt.plot(0, 0, color="black", marker="o")
plot_vector2d(v/la.norm(v), color="black")
plot_vector2d(v, color="blue", linestyle=":")
plt.text(0.3, 0.3, r"$\hat{v}$", color="black", fontsize=18)
plt.text(1.5, 0.7, "$v$", color="blue", fontsize=18)

plt.axis([-1.5, 5, -1.5, 3])
plt.gca().set_aspect("equal")
plt.grid()
plt.show()
# Out:
# v = [3 1]
# |v| = 3.1622776601683795
# v_hat = [0.9486833  0.31622777]

# %% [markdown]
# ## Dot product
#
# The dot product (also called *scalar product* or *inner product* in the context of the Euclidian space) of two vectors $\textbf{u}$ and $\textbf{v}$ is a useful operation that comes up fairly often in linear algebra. It is noted $\textbf{u} \cdot \textbf{v}$ and it is defined as:
#
# $\textbf{u} \cdot \textbf{v} = \left \Vert \textbf{u} \right \| \times \left \Vert \textbf{v} \right \| \times cos(\theta)$
#
# where $\theta$ is the angle between $\textbf{u}$ and $\textbf{v}$.
#
# Another way to calculate the dot product is:
#
# $\textbf{u} \cdot \textbf{v} = \sum_i{\textbf{u}_i \times \textbf{v}_i}$

# %%
def dot_product(v1, v2):
    return sum(v1i*v2i for v1i, v2i in zip(v1, v2))

print(f"u = {u}")
print(f"v = {v}")
print(f"u.v = {dot_product(u, v)}")
# Out:
# u = [2 5]
# v = [3 1]
# u.v = 11

# %% [markdown]
# But a *much* more efficient implementation is provided by NumPy with the `np.dot()` function:

# %%
print(f"u = {u}")
print(f"v = {v}")
print(f"u.v = {np.dot(u, v)}")
# Out:
# u = [2 5]
# v = [3 1]
# u.v = 11

# %% [markdown]
# Equivalently, you can use the `dot` method of `ndarray`s:

# %%
print(f"u = {u}")
print(f"v = {v}")
print(f"u.v = {u.dot(v)}")
# Out:
# u = [2 5]
# v = [3 1]
# u.v = 11

# %% [markdown]
# **Caution**: the `*` operator will perform an *elementwise* multiplication, *NOT* a dot product:

# %%
print(f"u = {u}")
print(f"v = {v}")
print(f"u * v = {u * v} (NOT a dot product)")
# Out:
# u = [2 5]
# v = [3 1]
# u * v = [6 5] (NOT a dot product)

# %% [markdown]
# ### Main properties
# * The dot product is **commutative**: $\textbf{u} \cdot \textbf{v} = \textbf{v} \cdot \textbf{u}$.
# * The dot product is only defined between two vectors, not between a scalar and a vector. This means that we cannot chain dot products: for example, the expression $\textbf{u} \cdot \textbf{v} \cdot \textbf{w}$ is not defined since $\textbf{u} \cdot \textbf{v}$ is a scalar and $\textbf{w}$ is a vector.
# * This also means that the dot product is **NOT associative**: $(\textbf{u} \cdot \textbf{v}) \cdot \textbf{w} ≠ \textbf{u} \cdot (\textbf{v} \cdot \textbf{w})$ since neither are defined.
# * However, the dot product is **associative with regards to scalar multiplication**: $\lambda \times (\textbf{u} \cdot \textbf{v}) = (\lambda \times \textbf{u}) \cdot \textbf{v} = \textbf{u} \cdot (\lambda \times \textbf{v})$
# * Finally, the dot product is **distributive** over addition of vectors: $\textbf{u} \cdot (\textbf{v} + \textbf{w}) = \textbf{u} \cdot \textbf{v} + \textbf{u} \cdot \textbf{w}$.

# %% [markdown]
# ### Calculating the angle between vectors
# One of the many uses of the dot product is to calculate the angle between two non-zero vectors. Looking at the dot product definition, we can deduce the following formula:
#
# $\theta = \arccos{\left ( \dfrac{\textbf{u} \cdot \textbf{v}}{\left \Vert \textbf{u} \right \| \times \left \Vert \textbf{v} \right \|} \right ) }$
#
# Note that if $\textbf{u} \cdot \textbf{v} = 0$, it follows that $\theta = \dfrac{π}{2}$. In other words, if the dot product of two non-null vectors is zero, it means that they are orthogonal.
#
# Let's use this formula to calculate the angle between $\textbf{u}$ and $\textbf{v}$ (in radians):

# %%
def vector_angle(u, v):
    cos_theta = np.dot(u, v) / (la.norm(u) * la.norm(v))
    return np.arccos(cos_theta.clip(-1, 1))

print(f"u = {u}")
print(f"v = {v}")
theta_radians = vector_angle(u, v)
theta_degrees = theta_radians * 180 / np.pi
print(f"Angle between u and v = {theta_radians} radians = {theta_degrees} degrees")
# Out:
# u = [2 5]
# v = [3 1]
# Angle between u and v = 0.8685393952858896 radians = 49.76364169072618 degrees

# %% [markdown]
# Note: due to small floating point errors, `cos_theta` may be very slightly outside the $[-1, 1]$ interval, which would make `arccos` fail. This is why we clipped the value within the range, using NumPy's `clip` function.

# %% [markdown]
# ### Projecting a point onto an axis
# The dot product is also very useful to project points onto an axis. The projection of vector $\textbf{v}$ onto $\textbf{u}$'s axis is given by this formula:
#
# $\textbf{proj}_{\textbf{u}}{\textbf{v}} = \dfrac{\textbf{u} \cdot \textbf{v}}{\left \Vert \textbf{u} \right \| ^2} \times \textbf{u}$
#
# Which is equivalent to:
#
# $\textbf{proj}_{\textbf{u}}{\textbf{v}} = (\textbf{v} \cdot \hat{\textbf{u}}) \times \hat{\textbf{u}}$

# %%
print(f"u = {u}")
print(f"v = {v}")

u_normalized = u / la.norm(u)
proj = v.dot(u_normalized) * u_normalized
print(f"proj = {proj}")

plot_vector2d(u, color="red")
plot_vector2d(v, color="blue")

plot_vector2d(proj, color="black", linestyle=":")
plt.plot(proj[0], proj[1], color="black", marker="o")

plt.plot([proj[0], v[0]], [proj[1], v[1]], color="blue", linestyle=":")

plt.text(1, 2, "$proj_u v$", color="black", fontsize=18)
plt.text(1.8, 0.2, "$v$", color="blue", fontsize=18)
plt.text(0.8, 3, "$u$", color="red", fontsize=18)

plt.axis([0, 8, 0, 5.5])
plt.gca().set_aspect("equal")
plt.grid()
plt.show()
# Out:
# u = [2 5]
# v = [3 1]
# proj = [0.75862069 1.89655172]

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # References

# %% [markdown]
# - **Hands-On Machine Learning with Scikit-Learn and PyTorch by Aurélien Géron**

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %%
# Notebook Template

from IPython import display
display.Image("data/images/Notebook_Template-01.jpg")

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)
