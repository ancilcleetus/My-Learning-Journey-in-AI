# %% [markdown]
# # **SQL Crash Course**

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 📖 TABLE OF CONTENTS
#
# - [What is SQL?](#What-is-SQL?)
# - [Setup SQL in Jupyter Notebook](#Setup-SQL-in-Jupyter-Notebook)
# - [The SQL SELECT Statement](#The-SQL-SELECT-Statement)
# - [SELECT statement with specific columns](#SELECT-statement-with-specific-columns)
# - [Filtering results with the WHERE Clause](#Filtering-results-with-the-WHERE-Clause)
# - [Filtering results using the WHERE Clause and GREATER THAN](#Filtering-results-using-the-WHERE-Clause-and-GREATER-THAN)
# - [Filtering results using the WHERE Clause and the AND operator](#Filtering-results-using-the-WHERE-Clause-and-the-AND-operator)
# - [Filtering results using the WHERE Clause and the OR operator](#Filtering-results-using-the-WHERE-Clause-and-the-OR-operator)
# - [Filtering results using the WHERE Clause and the IN operator](#Filtering-results-using-the-WHERE-Clause-and-the-IN-operator)
# - [Filtering results using the WHERE Clause and the NOT operator](#Filtering-results-using-the-WHERE-Clause-and-the-NOT-operator)
# - [Using wildcard comparisons with the LIKE operator](#Using-wildcard-comparisons-with-the-LIKE-operator)
# - [Handling Dates](#Handling-Dates)
# - [Removing duplicates from results with the DISTINCT keyword](#Removing-duplicates-from-results-with-the-DISTINCT-keyword)
# - [Sorting results using ORDER BY](#Sorting-results-using-ORDER-BY)
# - [Using the CASE statement](#Using-the-CASE-statement)
# - [How to LIMIT the number of results returned](#How-to-LIMIT-the-number-of-results-returned)
# - [Counting the number of rows returned with COUNT](#Counting-the-number-of-rows-returned-with-COUNT)
# - [Counting the number of rows returned with COUNT and the WHERE clause](#Counting-the-number-of-rows-returned-with-COUNT-and-the-WHERE-clause)
# - [Summing all values using the SUM Function](#Summing-all-values-using-the-SUM-Function)
# - [Finding the average of numerical values using the AVG function](#Finding-the-average-of-numerical-values-using-the-AVG-function)
# - [Finding the minimum and maximum values using MIN and MAX functions](#Finding-the-minimum-and-maximum-values-using-MIN-and-MAX-functions)
# - [Aggregate functions using the GROUP BY clause](#Aggregate-functions-using-the-GROUP-BY-clause)
# - [Using the HAVING clause to filter aggregate functions](#Using-the-HAVING-clause-to-filter-aggregate-functions)
# - [Handling NULL values](#Handling-NULL-values)
# - [Using the COALESCE function](#Using-the-COALESCE-function)
# - [Using Nested Queries](#Using-Nested-Queries)
# - [Joining tables using INNER JOIN](#Joining-tables-using-INNER-JOIN)
# - [References](#References)

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # What is SQL?

# %% [markdown]
# SQL (**pronounced Sequel**) was developed by Donald Chamberlin and Raymond Boyce at IBM in the 1970s. SQL stands for **Structured Query Language**. It lets us take things out of relational database systems, put new rows of data into them, amend records that are in there and remove records we don’t need any more. It was recognised as the standard language for relational databases by the **American National Standards Institute** way back in 1986.
#
# All of the main relational database management systems (Microsoft SQL Server, PostgreSQL, MySQL, Oracle, DB2, SQLite etc) use a form of SQL. They mainly have some variations in syntax and functionality.
#
# In this SQL crash course, we are going to look at many areas of SQL:
# * Main SQL commands such as SELECT, UPDATE, INSERT INTO, DELETE
# * Functions such as SUM, COUNT, AVG
# * Joining tables using INNER JOIN, LEFT and RIGHT JOIN, OUTER JOIN and CROSS JOIN

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Setup SQL in Jupyter Notebook

# %% [markdown]
# **JupySQL** is a fork of ipython-sql that allows users to run SQL queries directly from a Jupyter Notebook in a cleaner way. This library eliminates the need to write multiple lines of code to connect to the database, or wrap the query in a string as in the other approaches. JupySQL is compatible with all major databases (e.g., PostgreSQL, MySQL, SQL Server), data warehouses (e.g., Snowflake, BigQuery, Redshift), and embedded engines (SQLite, and DuckDB).

# %%
# Setup (one time)
# !pip install jupysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 kB 12.0 MB/s eta 0:00:00
# ...

# %%
# Load the extension
# %load_ext sql

# %%
# Connect to a database
# %sql sqlite:///:memory:
# Out:
# Connecting to 'sqlite:///:memory:'

# %%
# Write SQL directly
# %%sql

CREATE TABLE characters (
    id INTEGER,
    name TEXT,
    alter_ego TEXT,
    eyes TEXT,
    gender TEXT,
    hair TEXT,
    height INTEGER,
    nationality TEXT
);

INSERT INTO characters VALUES
(1, 'Incredible Hulk', 'Bruce Banner', 'blue', 'male', 'blond', 188, 'American'),
(2, 'Iron Man', 'Tony Stark', 'red', 'male', 'brown', 182, 'American'),
(3, 'Captain America', 'Steve Rogers', 'blue', 'male', 'black', 176, 'American'),
(4, 'Thor', 'Thor Odinson', 'blue', 'male', 'blond', 198, 'Asgardian'),
(5, 'Black Widow', 'Natasha Romanoff', 'green', 'female', 'red', 170, 'Sokovian'),
(6, 'Wonder Woman', 'Diana Prince', 'blue', 'female', 'black', 183, 'Themysciran'),
(7, 'Scarlet Witch', 'Wanda Maximoff', 'brown', 'female', 'brown', 170, 'Sokovian'),
(8, 'Spider-Man', 'Peter Parker', 'brown', 'male', 'brown', 178, 'American'),
(9, 'Captain Marvel', 'Carol Danvers', 'blue', 'female', 'blond', 180, 'Kree-Human'),
(10, 'Catwoman', 'Selina Kyle', 'green', 'female', 'black', 175, 'Gothamite');
# Out:
# Running query in 'sqlite:///:memory:'
# 10 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # The SQL SELECT Statement

# %% [markdown]
# **SELECT lets you grab whatever data you want from the database**.
#
# SELECT * => * essentially means give me everything.
#
# We haven’t said where we want to get the data from however which brings us to the FROM part of the SELECT statement. This tells the database which table you want to get the information out of. Example: SELECT * FROM customers;

# %% [markdown]
# The database table `characters` contains data about selected characters from the **Marvel Cinematic Universe**. If we wanted to grab ALL of the character data from the `characters` table, we would use the following query:

# %%
# %%sql
#
# SELECT * FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | id |       name      |    alter_ego     |  eyes | gender |  hair | height | nationality |
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | 1  | Incredible Hulk |   Bruce Banner   |  blue |  male  | blond |  188   |   American  |
# | 2  |     Iron Man    |    Tony Stark    |  red  |  male  | brown |  182   |   American  |
# | 3  | Captain America |   Steve Rogers   |  blue |  male  | black |  176   |   American  |
# | 4  |       Thor      |   Thor Odinson   |  blue |  male  | blond |  198   |  Asgardian  |
# | 5  |   Black Widow   | Natasha Romanoff | green | female |  red  |  170   |   Sokovian  |
# | 6  |   Wonder Woman  |   Diana Prince   |  blue | female | black |  183   | Themysciran |
# | 7  |  Scarlet Witch  |  Wanda Maximoff  | brown | female | brown |  170   |   Sokovian  |
# ...

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # SELECT statement with specific columns

# %% [markdown]
# We've seen that SELECT * returns all of the columns in our data table.
#
# **Handy Real-Life Hint: don’t do this**.
#
# You can run into performance problems with this if you are hitting a big table or, worse, joining large tables together.
#
# If we want to get only the customer’s first name, date of birth and email address rather their full address and personal details from the `Customers` table, we would use the following query:
#
# ```
# SELECT firstname, dob, email FROM Customers;
# ```

# %% [markdown]
# SELECT * brings back too much data. But what would we query for if we only wanted to return the name of our superheroes from `characters` table?

# %%
# %%sql
#
# SELECT name FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-----------------+
# |       name      |
# +-----------------+
# | Incredible Hulk |
# |     Iron Man    |
# | Captain America |
# |       Thor      |
# |   Black Widow   |
# |   Wonder Woman  |
# |  Scarlet Witch  |
# |    Spider-Man   |
# |  Captain Marvel |
# |     Catwoman    |
# +-----------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Filtering results with the WHERE Clause

# %% [markdown]
# **The WHERE clause allows us to filter the results by a set of criteria**. Specifying the columns we want in our SELECT statement lets us limit the columns of data we return in our SQL query. If we want to filter the rows however based on certain criteria, we use the WHERE clause.
#
# If we want to only grab the products that are books from a `Products` table, we could use the query:
#
# ```
# SELECT * FROM Products WHERE product_type='book';
# ```

# %%
# %%sql
#
# SELECT * FROM characters WHERE eyes='red';
# Out:
# Running query in 'sqlite:///:memory:'
# +----+----------+------------+------+--------+-------+--------+-------------+
# | id |   name   | alter_ego  | eyes | gender |  hair | height | nationality |
# +----+----------+------------+------+--------+-------+--------+-------------+
# | 2  | Iron Man | Tony Stark | red  |  male  | brown |  182   |   American  |
# +----+----------+------------+------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Filtering results using the WHERE Clause and GREATER THAN

# %% [markdown]
# The WHERE clause also lets us use a range of other **comparison operators**:
#
# | Operator | Description |
# | :------- | :---------- |
# | = | Equal to |
# | != | NOT Equal to |
# | <> | NOT Equal to |
# | < | Less than |
# | <= | Less than OR Equal to |
# | > | Greater than |
# | >= | Greater than OR Equal to |

# %% [markdown]
# The **GREATER THAN** operator lets us filter our data table on numerical fields where the value is greater than the value we specify. For example, to get all products that cost more than $10 our query would be:
#
# ```
# SELECT * FROM Products WHERE price > 10;
# ```

# %% [markdown]
# SQL query that gets us all characters with height greater than 180cm:

# %%
# %%sql
#
# SELECT * FROM characters WHERE height > 180;
# Out:
# Running query in 'sqlite:///:memory:'
# +----+-----------------+--------------+------+--------+-------+--------+-------------+
# | id |       name      |  alter_ego   | eyes | gender |  hair | height | nationality |
# +----+-----------------+--------------+------+--------+-------+--------+-------------+
# | 1  | Incredible Hulk | Bruce Banner | blue |  male  | blond |  188   |   American  |
# | 2  |     Iron Man    |  Tony Stark  | red  |  male  | brown |  182   |   American  |
# | 4  |       Thor      | Thor Odinson | blue |  male  | blond |  198   |  Asgardian  |
# | 6  |   Wonder Woman  | Diana Prince | blue | female | black |  183   | Themysciran |
# +----+-----------------+--------------+------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Filtering results using the WHERE Clause and the AND operator

# %% [markdown]
# We can power up our **WHERE clause** even further by using more than one condition at a time. We can join conditions that **BOTH** have to be met using the **AND operator**.

# %% [markdown]
# Write a query that only brings back black-haired females from our character table:

# %%
# %%sql
#
# SELECT * FROM characters WHERE gender='female' AND hair='black';
# Out:
# Running query in 'sqlite:///:memory:'
# +----+--------------+--------------+-------+--------+-------+--------+-------------+
# | id |     name     |  alter_ego   |  eyes | gender |  hair | height | nationality |
# +----+--------------+--------------+-------+--------+-------+--------+-------------+
# | 6  | Wonder Woman | Diana Prince |  blue | female | black |  183   | Themysciran |
# | 10 |   Catwoman   | Selina Kyle  | green | female | black |  175   |  Gothamite  |
# +----+--------------+--------------+-------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Filtering results using the WHERE Clause and the OR operator

# %% [markdown]
# In the **WHERE clause** we can also tailor our results by joining conditions where **EITHER** of them can be met by using the **OR operator**.

# %% [markdown]
# Write a query that only brings back females with black or brown hair from our character table:

# %%
# %%sql
#
# SELECT * FROM characters WHERE gender='female' AND (hair='black' OR hair='brown');
# Out:
# Running query in 'sqlite:///:memory:'
# +----+---------------+----------------+-------+--------+-------+--------+-------------+
# | id |      name     |   alter_ego    |  eyes | gender |  hair | height | nationality |
# +----+---------------+----------------+-------+--------+-------+--------+-------------+
# | 6  |  Wonder Woman |  Diana Prince  |  blue | female | black |  183   | Themysciran |
# | 7  | Scarlet Witch | Wanda Maximoff | brown | female | brown |  170   |   Sokovian  |
# | 10 |    Catwoman   |  Selina Kyle   | green | female | black |  175   |  Gothamite  |
# +----+---------------+----------------+-------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Filtering results using the WHERE Clause and the IN operator

# %% [markdown]
# **Tidying up our WHERE clause with IN**.
#
# You can see from the previous **OR operator** example how your WHERE clause could get a little unwieldy after a while when using multiple different conditions. If we were also specifying date ranges, upper and lower price limits, types of holiday, number of passengers etc. as well it could become VERY untidy to read and maintain.
#
# We can do a little housekeeping to protect against that in our IDE by using brackets and liberal use of tabs. To tidy up the multiple OR conditions themselves we could also use the **IN statement**.

# %% [markdown]
# Use the IN keyword to bring back the same results i.e. every female character who has black OR brown hair:

# %%
# %%sql
#
# SELECT * FROM characters WHERE gender='female' AND hair IN ('black', 'brown');
# Out:
# Running query in 'sqlite:///:memory:'
# +----+---------------+----------------+-------+--------+-------+--------+-------------+
# | id |      name     |   alter_ego    |  eyes | gender |  hair | height | nationality |
# +----+---------------+----------------+-------+--------+-------+--------+-------------+
# | 6  |  Wonder Woman |  Diana Prince  |  blue | female | black |  183   | Themysciran |
# | 7  | Scarlet Witch | Wanda Maximoff | brown | female | brown |  170   |   Sokovian  |
# | 10 |    Catwoman   |  Selina Kyle   | green | female | black |  175   |  Gothamite  |
# +----+---------------+----------------+-------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Filtering results using the WHERE Clause and the NOT operator

# %% [markdown]
# **Flipping It Around**.
#
# When we use the **AND** operator in our WHERE clause we look for rows where **ALL** of the conditions are met.
#
# When we use the **OR** operator, we look for rows where **ANY** of the conditions are met.
#
# But what if we want to find out which rows **DON'T** meet the criteria we're filtering for? That's when we bring out the keyword **NOT**.

# %% [markdown]
# Write a query that only brings back females with hair not black nor brown from our character table:

# %%
# %%sql
#
# SELECT * FROM characters WHERE gender='female' AND hair NOT IN ('black', 'brown');
# Out:
# Running query in 'sqlite:///:memory:'
# +----+----------------+------------------+-------+--------+-------+--------+-------------+
# | id |      name      |    alter_ego     |  eyes | gender |  hair | height | nationality |
# +----+----------------+------------------+-------+--------+-------+--------+-------------+
# | 5  |  Black Widow   | Natasha Romanoff | green | female |  red  |  170   |   Sokovian  |
# | 9  | Captain Marvel |  Carol Danvers   |  blue | female | blond |  180   |  Kree-Human |
# +----+----------------+------------------+-------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Using wildcard comparisons with the LIKE operator

# %% [markdown]
# **Leveling up the WHERE clause with LIKE**.
#
# We can also step things up a gear when it comes to comparison operators on our **WHERE clause** by using the **LIKE operator**.
#
# Whereas the other operators (=, >, < etc.) allowed us to filter on specific strings or values, **LIKE** allows us to use patterns.
#
# By specifying a string fragment plus a wildcard character, we can do basic pattern matching within our data fields to really boost the power of our WHERE clause.

# %% [markdown]
# Putting a wildcard (%) either side lets us pattern match for our string anywhere in the data with no need to spcify how many wildcard characters we will allow. It means ANY string of characters can both come before and come after our pattern string.
#
# If we use the underscore (_) wildcard we can dictate exactly how many wildcard characters we want to search for in the string.

# %% [markdown]
# Example: We have a table of music bands `Bands` where the bands have colour-themed names like `'BlueTones'`, `'Blue Notes'`, `'Yellow Tunes' etc.
#
# If we only want to return those with the string "**Blue**" in their names and had to use only the basic comparison operators, we would need to know exactly which band names were in there and be VERY specific on each one:
#
# ```
# SELECT * FROM Bands WHERE BandName = 'BlueTones';
# ```
#
# In reality, the table could contain millions of rows that could conceivably contain our 'Blue' string and it's not practical to hardcode each one. So we use the **** operator and the percentage sign wildcard character (%), like this:
#
# ```
# SELECT * FROM Bands WHERE BandName LIKE '%Blue%';
# ```
#
# If we only wanted to return strings that had 'Blue' at the start of the string we would do this instead:
#
# ```
# SELECT * FROM Bands WHERE BandName LIKE 'Blue%';
# ```
#
# If we want to be very specific on the number of characters our wildcard allows for, we can't use the % sign. Instead we use the underscore character (_). It lets us dictate exactly how many wildcard characters we want to search. For example, if we only wanted band names of 10 characters we could put ten underscores in our WHERE clause with LIKE:
#
# ```
# SELECT * FROM Bands WHERE BandName LIKE '__________';
# ```

# %% [markdown]
# Write a query that only brings back characters with alter_ego ending with `'ers'` or `'off'` from our character table:

# %%
# %%sql
#
# SELECT * FROM characters WHERE alter_ego LIKE '%ers' OR alter_ego LIKE '%off';
# Out:
# Running query in 'sqlite:///:memory:'
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | id |       name      |    alter_ego     |  eyes | gender |  hair | height | nationality |
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | 3  | Captain America |   Steve Rogers   |  blue |  male  | black |  176   |   American  |
# | 5  |   Black Widow   | Natasha Romanoff | green | female |  red  |  170   |   Sokovian  |
# | 7  |  Scarlet Witch  |  Wanda Maximoff  | brown | female | brown |  170   |   Sokovian  |
# | 9  |  Captain Marvel |  Carol Danvers   |  blue | female | blond |  180   |  Kree-Human |
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Handling Dates

# %% [markdown]
# Let's go with a consistent date format for our examples. We'll ignore the disagreements between American date format and that used in many parts of the rest of the world. Instead we'll pretend that dates in databases all come in the **YYYY-MM-DD** format with the 4 digit Year then a dash then the 2 digit Month then a dash then the 2 digit Day. So 14th June 1978 becomes 1978-06-14.
#
# You only want customers born before the turn of the Millenium:
#
# ```
# SELECT firstname, dob, email FROM customers WHERE dob < '2000-01-01';
# ```

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Removing duplicates from results with the DISTINCT keyword

# %% [markdown]
# **Duplicates in data tables are a fact of life.**
#
# They can cause serious issues when performing calculations or counts if not properly de-duped. We can do this in the **SELECT statement** by using the **DISTINCT keyword**. This means only one "distinct" data row is returned for each combination of columns in our statement.
#
# ```
# SELECT DISTINCT Surname FROM PlayerNames;
# ```
#
# This would mean that no matter how many times a particular surname appeared in the "Surname" column of our table, our results would only bring it back ONCE.

# %% [markdown]
# Write a query to get a DISTINCT list of
# * different eye colours
# * different hair colours
# * different combinations of eye colours & hair colours
#
# of the characters in our table:

# %%
# %%sql
#
# SELECT DISTINCT eyes FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------+
# |  eyes |
# +-------+
# |  blue |
# |  red  |
# | green |
# | brown |
# +-------+

# %%
# %%sql
#
# SELECT DISTINCT hair FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------+
# |  hair |
# +-------+
# | blond |
# | brown |
# | black |
# |  red  |
# +-------+

# %%
# %%sql
#
# SELECT DISTINCT eyes, hair FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------+-------+
# |  eyes |  hair |
# +-------+-------+
# |  blue | blond |
# |  red  | brown |
# |  blue | black |
# | green |  red  |
# | brown | brown |
# | green | black |
# +-------+-------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Sorting results using ORDER BY

# %% [markdown]
# SQL isn't just about grabbing rows of data from our database tables. It's also useful for arranging and sorting the order of our results to make them easier to analyse.
#
# We can sort by specific columns and attributes by using the **ORDER BY** keyword.
#
# For example, we could sort our footballers by alphabetical order on their surnames as so:
#
# ```
# SELECT FirstName, Surname FROM footballers ORDER BY Surname;
# ```
#
# We could reverse the order of the sort by adding the additional keyword **DESC** at the end of the query:
#
# ```
# SELECT FirstName, Surname FROM footballers ORDER BY Surname DESC;
# ```

# %% [markdown]
# Write a query to get characters in both ascending & descending orders of name:

# %%
# %%sql
#
# SELECT * FROM characters ORDER BY name;
# Out:
# Running query in 'sqlite:///:memory:'
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | id |       name      |    alter_ego     |  eyes | gender |  hair | height | nationality |
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | 5  |   Black Widow   | Natasha Romanoff | green | female |  red  |  170   |   Sokovian  |
# | 3  | Captain America |   Steve Rogers   |  blue |  male  | black |  176   |   American  |
# | 9  |  Captain Marvel |  Carol Danvers   |  blue | female | blond |  180   |  Kree-Human |
# | 10 |     Catwoman    |   Selina Kyle    | green | female | black |  175   |  Gothamite  |
# | 1  | Incredible Hulk |   Bruce Banner   |  blue |  male  | blond |  188   |   American  |
# | 2  |     Iron Man    |    Tony Stark    |  red  |  male  | brown |  182   |   American  |
# | 7  |  Scarlet Witch  |  Wanda Maximoff  | brown | female | brown |  170   |   Sokovian  |
# ...

# %%
# %%sql
#
# SELECT * FROM characters ORDER BY name DESC;
# Out:
# Running query in 'sqlite:///:memory:'
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | id |       name      |    alter_ego     |  eyes | gender |  hair | height | nationality |
# +----+-----------------+------------------+-------+--------+-------+--------+-------------+
# | 6  |   Wonder Woman  |   Diana Prince   |  blue | female | black |  183   | Themysciran |
# | 4  |       Thor      |   Thor Odinson   |  blue |  male  | blond |  198   |  Asgardian  |
# | 8  |    Spider-Man   |   Peter Parker   | brown |  male  | brown |  178   |   American  |
# | 7  |  Scarlet Witch  |  Wanda Maximoff  | brown | female | brown |  170   |   Sokovian  |
# | 2  |     Iron Man    |    Tony Stark    |  red  |  male  | brown |  182   |   American  |
# | 1  | Incredible Hulk |   Bruce Banner   |  blue |  male  | blond |  188   |   American  |
# | 10 |     Catwoman    |   Selina Kyle    | green | female | black |  175   |  Gothamite  |
# ...

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Using the CASE statement

# %% [markdown]
# The **CASE statement** in SQL allows you to create a new variable and set the values based on a series of conditions being met.
#
# Reducing data redundancy is one of our ideal database design states. Don't have something in there if it's not absolutely necessary. By using the CASE statement, we can change the business logic on the fly at any time. This causes a lot less problems than having to change the underlying data in our database.

# %% [markdown]
# We want to describe characters using `height` (eg: '< 175', '175 - 180', '181 - 185', '186-190', '> 190'). Write SQL query to return character names along with this description:

# %%
# %%sql
#
# SELECT name,
#     CASE
#         WHEN height < 175 THEN '< 175'
#         WHEN height >= 175 AND height <= 180 THEN '175 - 180'
#         WHEN height >= 181 AND height <= 185 THEN '181 - 185'
#         WHEN height >= 186 AND height <= 190 THEN '186 - 190'
#         WHEN height > 190 THEN '> 190'
#         ELSE 'Unknown'
#     END AS height_description
# FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-----------------+--------------------+
# |       name      | height_description |
# +-----------------+--------------------+
# | Incredible Hulk |     186 - 190      |
# |     Iron Man    |     181 - 185      |
# | Captain America |     175 - 180      |
# |       Thor      |       > 190        |
# |   Black Widow   |       < 175        |
# |   Wonder Woman  |     181 - 185      |
# |  Scarlet Witch  |       < 175        |
# |    Spider-Man   |     175 - 180      |
# |  Captain Marvel |     175 - 180      |
# |     Catwoman    |     175 - 180      |
# +-----------------+--------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # How to LIMIT the number of results returned

# %% [markdown]
# **When you only want a few rows back.**
#
# Sometimes you don't want to bring back every row in a table. We've already seen how we can limit the columns returned by our query by specifying column names in our **SELECT statement**. We can also filter the rows returned by being a little more focused when we put together our **WHERE clause**.
#
# But what if we only want a certain number of rows for a sample of data? The LIMIT clause allows us to specify how many rows our query brings back. In our SQL query it should come last, after the ORDER BY clause:
#
# ```
# SELECT * FROM EnglishMonarchs WHERE FirstName = 'Elizabeth'
# ORDER BY CoronationDate
# LIMIT 1;
# ```
#
# This query would bring us back one single row (LIMIT 1) from our table of English Monarchs with the first name of Elizabeth, ordered in ascending order by the date of their Coronation. In this case it would return "Elizabeth I".
#
# If we set the LIMIT clause to "LIMIT 2" then it would bring back two rows - in this example both Elizabeth I and Elizabeth II.
#
# **When would I use this?**
# * You may just want to get a taste for some live data to do some further investigation into the structure and components it holds. There's no sense returning one million rows in that case when you can do a LIMIT 20 and only bring back twenty.
#
# **Does it work on all flavours of SQL?**
# * No. Microsoft being Microsoft had to do things a little differently in their own SQL dialect used in MS SQL Server and MS Access. There we use the "**SELECT TOP**" statement instead:
#
# ```
# SELECT TOP 2
# FROM EnglishMonarchs
# WHERE FirstName = 'Elizabeth'
# ORDER BY CoronationDate;
# ```

# %% [markdown]
# SQL query to get first 2 characters with blond hair ordered by their names:

# %%
# %%sql
#
# SELECT * FROM characters WHERE hair = 'blond'
# ORDER BY name
# LIMIT 2;
# Out:
# Running query in 'sqlite:///:memory:'
# +----+-----------------+---------------+------+--------+-------+--------+-------------+
# | id |       name      |   alter_ego   | eyes | gender |  hair | height | nationality |
# +----+-----------------+---------------+------+--------+-------+--------+-------------+
# | 9  |  Captain Marvel | Carol Danvers | blue | female | blond |  180   |  Kree-Human |
# | 1  | Incredible Hulk |  Bruce Banner | blue |  male  | blond |  188   |   American  |
# +----+-----------------+---------------+------+--------+-------+--------+-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Counting the number of rows returned with COUNT

# %% [markdown]
# **Starting with functions.**
#
# SQL functions such as COUNT, SUM, MIN, MAX and AVG all let you perform basic mathematical operations on your data.
#
# The **COUNT** function allows you to count the number of rows in your table. You can use the asterisk (*) wildcard to count everything.

# %% [markdown]
# SQL query to get the count of characters:

# %%
# %%sql
#
# SELECT COUNT(*) FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +----------+
# | COUNT(*) |
# +----------+
# |    10    |
# +----------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Counting the number of rows returned with COUNT and the WHERE clause

# %% [markdown]
# As we did before with our `SELECT *` query, we can filter specific rows in our table while using our `COUNT(*)` function. This will allow us to only count the rows in the table where the specified condition in the **WHERE clause** is met.

# %% [markdown]
# SQL query to get the count of female characters:

# %%
# %%sql
#
# SELECT COUNT(*) FROM characters WHERE gender = 'female';
# Out:
# Running query in 'sqlite:///:memory:'
# +----------+
# | COUNT(*) |
# +----------+
# |    5     |
# +----------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Summing all values using the SUM Function

# %% [markdown]
# The **SUM function** allows you to do a summary calculation on a particular column in your data table. No wildcards here, we **MUST** specify the individual column we want to summarise.
#
# The easiest way to think about the SUM function is to use it to add up all of the values in a particular column.

# %% [markdown]
# If we want to find the total height of our characters, our SQL query would look like this:

# %%
# %%sql
#
# SELECT SUM(height) FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+
# | SUM(height) |
# +-------------+
# |     1800    |
# +-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Finding the average of numerical values using the AVG function

# %% [markdown]
# If we want to find out what the AVERAGE (or MEAN) value within a specified column is, we use the **AVG function**.

# %% [markdown]
# If we want to find the average height of our characters, our SQL query would look like this:

# %%
# %%sql
#
# SELECT AVG(height) FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+
# | AVG(height) |
# +-------------+
# |    180.0    |
# +-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Finding the minimum and maximum values using MIN and MAX functions

# %% [markdown]
# If we want to find out what the highest value within a specified column is, we use the MAX function. This gives us the MAXIMUM value.
#
# SQL query to find maximum height of characters will be:

# %%
# %%sql
#
# SELECT MAX(height) FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+
# | MAX(height) |
# +-------------+
# |     198     |
# +-------------+

# %% [markdown]
# If we want to find out what the lowest value within a specified column is, we use the MIN function. This gives us the MINIMUM value.
#
# SQL query to find minimum height of characters will be:

# %%
# %%sql
#
# SELECT MIN(height) FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+
# | MIN(height) |
# +-------------+
# |     170     |
# +-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Aggregate functions using the GROUP BY clause

# %% [markdown]
# Using your new-found SQL function (COUNT, SUM, AVG, MIN, MAX) superpowers on the whole data table won't happen as often as you might hope. It's more useful to our business area if we are able to split our data up into smaller segments to allow greater comparison across these very, very useful aggregated functions.
#
# So we need a way to group togther certain data points to allow us to perform our functions and get a more useable result. And we do that with the **GROUP BY clause**.
#
# SQL query to get the count of characters for each nationality is:

# %%
# %%sql
#
# SELECT nationality, COUNT(id) FROM characters
# GROUP BY nationality;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+-----------+
# | nationality | COUNT(id) |
# +-------------+-----------+
# |   American  |     4     |
# |  Asgardian  |     1     |
# |  Gothamite  |     1     |
# |  Kree-Human |     1     |
# |   Sokovian  |     2     |
# | Themysciran |     1     |
# +-------------+-----------+

# %%
# %%sql
#
# SELECT nationality, COUNT(*) FROM characters
# GROUP BY nationality;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+----------+
# | nationality | COUNT(*) |
# +-------------+----------+
# |   American  |    4     |
# |  Asgardian  |    1     |
# |  Gothamite  |    1     |
# |  Kree-Human |    1     |
# |   Sokovian  |    2     |
# | Themysciran |    1     |
# +-------------+----------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Using the HAVING clause to filter aggregate functions

# %% [markdown]
# SQL queries run in a standard order. First the **FROM** and **JOINs** are executed so SQL knows what set of data to do the rest of the work on. Next is the **WHERE clause** so it can filter out individual rows that don't meet the criteria.
#
# After this SQL goes to the **GROUP BY clause** to group up the data based on common values specified. Which leaves us with a conundrum if we want to filter on the aggregate functions the GROUP BY is helping us with. WHERE is no good to us as it's already shot it's bolt in the running order.
#
# So the **HAVING clause** was introduced to SQL to allow us to apply filters and constraints to the grouped data and aggregate functions. We bring in the HAVING clause **AFTER** the GROUP BY clause.

# %% [markdown]
# We only want to count the number of superheroes by nationality when there are more than one of that nationality present. Corresponding SQL query is:

# %%
# %%sql
#
# SELECT nationality, COUNT(*) FROM characters
# GROUP BY nationality
# HAVING COUNT(*) > 1;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+----------+
# | nationality | COUNT(*) |
# +-------------+----------+
# |   American  |    4     |
# |   Sokovian  |    2     |
# +-------------+----------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Handling NULL values

# %% [markdown]
# **What's the difference between zero and null?** Zero means there is none. Null means it does not exist. The two are **VERY** different.
#
# Difference between zero and null is illustrated in the figure below:

# %%
from IPython.display import Image, display, Markdown
display(Image(filename="data/images/SQL_Crash_Course_01.jpg", width=500))
display(Markdown("*On the left, there is zero toilet roll. On the right, there is null.*"))
# Out:
# *On the left, there is zero toilet roll. On the right, there is null.*

# %% [markdown]
# **Why do I need to care aboout NULLs?**
# * Nulls can seriously mess up your data analysis. Good database design usually says that reducing the possibility of NULLS in your database is the best plan. There may be valid and logical reasons for this not being the case with some of your data fields however.
#
# **What can NULLs mess up?**
# * Aggregate functions in SELECT statements are a particular danger area when it comes to NULL values. Not adequately understanding the impact of a lot of NULLs in your results can then lead to erroneous analysis and reporting. Not good.
#
# **How do we deal with them?**
# * We can do it in our SQL code in a few different ways.
#
#     * Use **COALESCE** to replace the null values with appropriate default replacements (refer next topic).
#
#     * Use an "**IS NULL**" or "**IS NOT NULL**" condition in your WHERE clause

# %% [markdown]
# If we have missing values in `height` column in characters table, we can use below SQL query to get average height:

# %%
# %%sql
#
# SELECT AVG(height) FROM characters WHERE height IS NOT NULL;
# Out:
# Running query in 'sqlite:///:memory:'
# +-------------+
# | AVG(height) |
# +-------------+
# |    180.0    |
# +-------------+

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Using the COALESCE function

# %% [markdown]
# **What does COALESCE do?**
# * The COALESCE function lets us take several columns within one row of our data and return the first column that has a non-NULL value. If all columns specified are NULL then we can set a default value in the COALESCE function.
#
# **Why would this be useful?**
# * NULLs can be rather destructive when introduced to aggregate functions like **AVG**. If our database design allows NULL values in a numerical field, we might want to swap those NULLs in the data into zeroes in our SQL query.
#
# If an employee had no entry for `HolidaysTaken` in the `AnnualLeave` table then COALESCE would find NULL for `HolidaysTaken`, move on to the next value and return the `0` we set as a default. It can then safely do an average calculation.
#
# ```
# SELECT AVG(COALESCE(HolidaysTaken, 0)) FROM AnnualLeave;
# ```
#
# **Using COALESCE across multiple columns**
#
# We could also use COALESCE to consolidate several columns into a "**best fit**" value amongst them. Imagine our `Customers` table had three separate fields `HomePhone`, `MobilePhone`, `BusinessPhone` for Home Phone Number, Mobile Phone Number and Business Phone Number. All allow NULL values as not every customer would have all of those means of contact.
#
# If we wanted to run a telephone marketing campaign to contact them with a marvellous new product offer, we need a phone number to reach them on. If the order of preference is Home - Mobile - Business, we would write our COALESCE function like this:
#
# ```
# SELECT CustomerName, COALESCE(HomePhone, MobilePhone, BusinessPhone) as PhoneNumber
# FROM Customers;
# ```
#
# The COALESCE function then checks each of the given columns in turn and returns the first one that has a non-NULL value as `PhoneNumber`. If none do then it returns NULL.

# %% [markdown]
# We can use COALESCE to substitute in the character's name if they have a NULL value for their Alter Ego name using below SQL query:

# %%
# %%sql
#
# SELECT COALESCE(alter_ego, name) FROM characters;
# Out:
# Running query in 'sqlite:///:memory:'
# +---------------------------+
# | COALESCE(alter_ego, name) |
# +---------------------------+
# |        Bruce Banner       |
# |         Tony Stark        |
# |        Steve Rogers       |
# |        Thor Odinson       |
# |      Natasha Romanoff     |
# |        Diana Prince       |
# |       Wanda Maximoff      |
# |        Peter Parker       |
# |       Carol Danvers       |
# |        Selina Kyle        |
# +---------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Using Nested Queries

# %% [markdown]
# **A dream within a dream. Welcome to the SQL Inception.**
# * There may be times in your SQL querying career that you will need to put one SQL query inside another SQL query. This is called **nesting queries**.
#
# It's possible then to use the results of a sub-query to help filter the results of the outer query.
#
# **What do Nested Queries look like and why would we use them?**
# * In our WHERE clause examples we have hardcoded the values we wanted to use in our comparisons. In some cases however, we may not want to hardcode the value as we might not know it OR it may change over time as our underlying data changes.

# %% [markdown]
# We want to get characters with minimum height from characters table, but we don't know the minimum height. SQL query will be:

# %%
# %%sql
#
# SELECT * FROM characters WHERE height = (SELECT MIN(height) FROM characters);
# Out:
# Running query in 'sqlite:///:memory:'
# +----+---------------+------------------+-------+--------+-------+--------+-------------+
# | id |      name     |    alter_ego     |  eyes | gender |  hair | height | nationality |
# +----+---------------+------------------+-------+--------+-------+--------+-------------+
# | 5  |  Black Widow  | Natasha Romanoff | green | female |  red  |  170   |   Sokovian  |
# | 7  | Scarlet Witch |  Wanda Maximoff  | brown | female | brown |  170   |   Sokovian  |
# +----+---------------+------------------+-------+--------+-------+--------+-------------+

# %% [markdown]
# **What did we do there?**
# * In the nested query `SELECT MIN(height) FROM characters`, we queried the minimum height in the `characters` table. The value this SQL query returned was then used in the WHERE clause EQUAL TO comparison in the outer query i.e. `WHERE height =`.
# * We don't have to know the actual minimum height, the Nested Query does all of the hard work for us.

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # Joining tables using INNER JOIN

# %% [markdown]
# **How do we join data tables?**
# * We link tables together using fields in the tables known as **"KEYS"**. Each table should have a field (or collection of fields) which operates as a unique identifier. This is known as a **PRIMARY** key.
#
# * To join to another table we also need a **FOREIGN** key. A FOREIGN key is a field or collection of fields which corresponds to a PRIMARY key in another table.
#
# **The INNER JOIN**
# * The INNER JOIN (also known simply as JOIN) lets us join together two tables and only bring back all records in both where the PRIMARY and FOREIGN keys match. We join ON the PRIMARY key in the parent table and the FOREIGN key in the child table. There **MUST** be a matching connection to return the record. If not we won't get it back.
#
# To return all rows and columns from both the `Movies` table and the `Actors` table but only if there is an Actor in the `Actors` table that is also in the `Movies` table, we can use below SQL query:
#
# ```
# SELECT *
# FROM Movies
# INNER JOIN Actors
# ON Movies.ActorID = Actors.ActorID;
# ```

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # References

# %% [markdown]
# - **[SQL Crash Course](https://sqlcrashcourse.com/)**

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)
